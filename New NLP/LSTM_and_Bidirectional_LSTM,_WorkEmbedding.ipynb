# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Step 1: Dataset Import (Dependant and Independant variable)

# %%
# importing the Dataset
import pandas as pd
reviews = pd.read_csv('/content/drive/MyDrive/NLP DataSet/imdb_master.csv',usecols=["review", "label"],
                      encoding='ISO-8859-1').sample(n=500)
reviews.head()
# Out:
#                                                   review  label
# 84620  I've seen other Olsen Twins movies, and most o...  unsup
# 94998  OK. First things first. When I watch a film I ...  unsup
# 785    ... but had to see just how bad it could get. ...    neg
# 41753  It must have been several years after it was r...    pos
# 38027  A friend of mine recommended this movie, citin...    pos

# %%
reviews['label'].value_counts()
# Out:
# unsup    243
# neg      142
# pos      115
# Name: label, dtype: int64

# %% [markdown]
# # Step 2: Cleaning the Dataset ( Tokenization, Stopwords, Stemmimg or Lemmitization)

# %%
#Data cleaning and preprocessing
import re
import nltk
nltk.download('stopwords')
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer
ps = PorterStemmer()
lemma=WordNetLemmatizer()

# %%
# For Lemmatizer
corpus = []
for i in range(0, len(reviews)):
    review = re.sub('[^a-zA-Z]', ' ', str(reviews['review'].iloc[i]))
    review = review.lower()
    review = review.split()

    review = [lemma.lemmatize(word) for word in review if not word in stopwords.words('english')]
    review = ' '.join(review)
    corpus.append(review)

# %%
#  just print to see Corpus
corpus

# %% [markdown]
# # Step 3: One Hot Encoding via Vocabulary size

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.15.0

# %%
##tensorflow >2.0
from tensorflow.keras.preprocessing.text import one_hot

# %% [markdown]
# One Hot Reprensentation

# %%
### Vocabulary size
voc_size=100

# %%
onehot_repr=[one_hot(words,voc_size)for words in corpus]
print(onehot_repr)
# Out:
# [[31, 22, 69, 69, 20, 52, 27, 38, 37, 12, 16, 68, 33, 52, 96, 95, 69, 36, 23, 93, 18, 69, 23, 37, 12, 84, 32, 66, 5, 84, 42, 76, 52, 28, 32, 25, 82, 24, 69, 12, 29], [20, 43, 28, 43, 48, 54, 31, 92, 44, 61, 92, 64, 39, 90, 85, 44, 44, 43, 96, 54, 91, 95, 48, 11, 33, 12, 78, 41, 12, 1, 65, 76, 44, 17, 41, 27, 49, 79, 35, 87, 84, 44, 21, 84, 69, 5, 5, 15, 95, 59, 85, 5, 44, 44, 13, 38, 72, 43, 68, 53, 15, 45, 28, 13, 89, 85, 2, 16, 54, 20, 34, 10, 9, 71, 52, 33, 68, 29, 26, 10, 11, 83, 35, 90, 54, 31, 25, 52, 23, 44, 44, 54, 82, 63, 10, 66, 59, 26, 7, 15, 84, 8, 44, 31, 85, 53, 59, 46, 3, 62, 57, 63, 15, 72, 89, 30, 17, 92, 68, 18, 44, 44, 75, 56, 54, 48, 44, 89, 85, 44, 44, 8, 2, 45, 8, 88, 58, 54, 49, 55, 35, 55, 52, 10, 44, 54, 26, 23, 22, 29, 62, 53, 28, 69, 90, 23, 64, 31, 4, 96, 44, 44, 20, 44, 8, 54, 52, 53, 22, 19, 27, 60, 50, 58, 87, 48, 69, 13, 89, 50, 38], [45, 69, 2, 19, 22, 53, 92, 9, 31, 44, 85, 87, 92, 37, 62, 71, 51, 67, 90, 64, 17, 11, 5, 60, 3, 12, 50, 65, 11, 35, 60, 1, 88, 33, 28, 5, 92, 37, 59, 18, 16, 69, 58, 53,
, 45, 47], [48, 18, 59, 16, 69, 75, 87, 69, 67, 53, 93, 13, 59, 10, 29, 33, 52, 38, 54, 24, 69, 44, 42, 41, 93, 27, 83, 38, 97, 71, 66, 51, 40, 54, 91, 38, 67, 69, 59, 50, 52, 48, 59, 54, 4, 99, 47, 28, 53, 52, 41], [40, 99, 46, 56, 14, 28, 90, 48, 79, 48, 43, 75, 13, 24, 74, 24, 89, 59, 7, 39, 11, 29, 74, 43, 68, 58, 48, 43, 38, 24, 8, 6, 62, 95, 90, 80, 56, 77, 39, 11, 86, 92, 1, 73, 22, 16, 38, 48, 28, 53, 66, 18, 56, 81, 38, 73, 48, 7, 25, 48, 66, 58, 61, 55, 44, 44, 17, 91, 51, 24, 85, 65, 14, 21, 45, 27, 62, 68, 51, 68, 15, 54, 56, 76, 44, 44, 46, 23, 8, 15, 55, 24, 54, 17, 32, 56, 38, 29, 73, 85, 11, 20, 97, 80, 11, 47, 27, 93, 77, 16, 66, 62, 15, 45, 49, 25, 42, 29, 43, 44, 44, 48, 32, 47, 3, 44, 44, 30, 30, 74, 25, 68, 25, 32, 30, 56, 98, 6, 31, 8, 30, 45, 16, 85, 50, 5, 97, 85, 90, 8, 48, 27, 29, 13, 76, 31, 33, 20, 56, 4, 96, 8, 30, 13, 73, 29, 9, 63, 44, 44, 30, 62, 38, 13, 45, 50, 43, 68, 57, 38, 5, 26, 71, 85, 2, 32, 11, 45, 41, 67, 38, 59, 17, 35, 53, 8, 5, 20, ...

# %% [markdown]
# ##### Word Embedding Representation

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import Bidirectional
import numpy as np

# %% [markdown]
# # Step 4: Pre or Post Padding

# %%
## post padding
sent_length=50
embedded_docs=pad_sequences(onehot_repr,padding='post',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[31 22 69 ...  0  0  0]
#  [ 8  2 45 ... 89 50 38]
#  [69 39 59 ... 67 52 88]
#  ...
#  [66 78 82 ... 74 69 64]
#  [90 93 99 ... 95  4 91]
#  [54 68 44 ... 40 92  6]]

# %% [markdown]
# # Step 5: Feature Representation
# ##### That is 40 features for each word of a sentences that is 500 sentences

# %%
##features representation
embedding_vector_features=40

# %% [markdown]
# # Step 6: Model Building LSTM

# %%
##Creating model
model=Sequential()
model.add(Embedding(voc_size,embedding_vector_features,input_length=sent_length))
model.add(LSTM(100))
model.add(Dense(3,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_2 (Embedding)     (None, 50, 40)            4000
#
#  lstm_2 (LSTM)               (None, 100)               56400
#
#  dense_2 (Dense)             (None, 3)                 303
#
# =================================================================
# Total params: 60703 (237.12 KB)
# Trainable params: 60703 (237.12 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
## For Dependant Variable
y=pd.get_dummies(reviews['label'])
# y=y.iloc[:,2].values
print(y)
# Out:
#        neg  pos  unsup
# 84620    0    0      1
# 94998    0    0      1
# 785      1    0      0
# 41753    0    1      0
# 38027    0    1      0
# ...    ...  ...    ...
# 43329    0    1      0
# 7223     1    0      0
# 49666    0    1      0
# 47266    0    1      0
# 47603    0    1      0
#
# [500 rows x 3 columns]

# %%
# Converting it to arrays
X_final=np.array(embedded_docs)
y_final=np.array(y)
X_final.shape,y_final.shape
# here 500 means 500 sentences which is imported and 50 is the independant features also the sent_length (which was set) and 3 catagories
# Out:
# ((500, 50), (500, 3))

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_final, y_final, test_size=0.33, random_state=42)

# %% [markdown]
# ##### Model Training

# %%
### Finally Training
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=10,batch_size=64)
# Out:
# Epoch 1/10
# 6/6 [==============================] - 3s 107ms/step - loss: 1.0916 - accuracy: 0.4627 - val_loss: 1.0756 - val_accuracy: 0.4848
# Epoch 2/10
# 6/6 [==============================] - 0s 47ms/step - loss: 1.0668 - accuracy: 0.4866 - val_loss: 1.0497 - val_accuracy: 0.4848
# Epoch 3/10
# 6/6 [==============================] - 0s 16ms/step - loss: 1.0491 - accuracy: 0.4866 - val_loss: 1.0455 - val_accuracy: 0.4848
# Epoch 4/10
# 6/6 [==============================] - 0s 50ms/step - loss: 1.0423 - accuracy: 0.4866 - val_loss: 1.0457 - val_accuracy: 0.4848
# Epoch 5/10
# 6/6 [==============================] - 0s 17ms/step - loss: 1.0377 - accuracy: 0.4866 - val_loss: 1.0414 - val_accuracy: 0.4848
# Epoch 6/10
# 6/6 [==============================] - 0s 18ms/step - loss: 1.0323 - accuracy: 0.4866 - val_loss: 1.0420 - val_accuracy: 0.4848
# Epoch 7/10
# 6/6 [==============================] - 0s 16ms/step - loss: 1.0245 - accuracy: 0.4866 - val_loss: 1.0430 - val_accuracy: 0.4848
# Epoch 8/10
# 6/6 [==============================] - 0s 16ms/step - loss: 1.0198 - accuracy: 0.4866 - val_loss: 1.0492 - val_accuracy: 0.4848
# Epoch 9/10
# 6/6 [==============================] - 0s 16ms/step - loss: 1.0083 - accuracy: 0.4866 - val_loss: 1.0469 - val_accuracy: 0.4848
# Epoch 10/10
# 6/6 [==============================] - 0s 17ms/step - loss: 0.9853 - accuracy: 0.4866 - val_loss: 1.0425 - val_accuracy: 0.4848

# %% [markdown]
# # Step 7: Prediction and Performation for LSTM

# %%
y_pred=model.predict(X_test)
# y_pred=np.where(y_pred > 0.6, 1,0) ##AUC ROC Curve
y_pred = (y_pred > 0.2)
# Out:
# 6/6 [==============================] - 1s 5ms/step

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.32      0.98      0.48        53
#            1       0.22      0.91      0.35        32
#            2       0.48      1.00      0.65        80
#
#    micro avg       0.35      0.98      0.52       165
#    macro avg       0.34      0.96      0.50       165
# weighted avg       0.38      0.98      0.54       165
#  samples avg       0.36      0.98      0.52       165

# %% [markdown]
# ## End of LSTM

# %% [markdown]
# # Step 6: Model Building Bidirectional LSTM

# %%
##Creating model
model=Sequential()
model.add(Embedding(voc_size,embedding_vector_features,input_length=sent_length))
model.add(Bidirectional(LSTM(100)))
model.add(Dense(3,activation='softmax'))
model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
print(model.summary())
# Out:
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_4 (Embedding)     (None, 50, 40)            4000
#
#  bidirectional_2 (Bidirecti  (None, 200)               112800
#  onal)
#
#  dense_4 (Dense)             (None, 3)                 603
#
# =================================================================
# Total params: 117403 (458.61 KB)
# Trainable params: 117403 (458.61 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________
# None

# %%
## Model Training
model.fit(X_train,y_train,validation_data=(X_test,y_test),epochs=20,batch_size=32)
# Out:
# Epoch 1/20
# 11/11 [==============================] - 4s 101ms/step - loss: 1.0824 - accuracy: 0.4657 - val_loss: 1.0530 - val_accuracy: 0.4848
# Epoch 2/20
# 11/11 [==============================] - 0s 17ms/step - loss: 1.0470 - accuracy: 0.4866 - val_loss: 1.0459 - val_accuracy: 0.4848
# Epoch 3/20
# 11/11 [==============================] - 0s 18ms/step - loss: 1.0429 - accuracy: 0.4866 - val_loss: 1.0436 - val_accuracy: 0.4848
# Epoch 4/20
# 11/11 [==============================] - 0s 15ms/step - loss: 1.0365 - accuracy: 0.4866 - val_loss: 1.0474 - val_accuracy: 0.4848
# Epoch 5/20
# 11/11 [==============================] - 0s 14ms/step - loss: 1.0228 - accuracy: 0.4866 - val_loss: 1.0405 - val_accuracy: 0.4848
# Epoch 6/20
# 11/11 [==============================] - 0s 17ms/step - loss: 1.0068 - accuracy: 0.4866 - val_loss: 1.0449 - val_accuracy: 0.4848
# Epoch 7/20
# 11/11 [==============================] - 0s 14ms/step - loss: 0.9809 - accuracy: 0.4896 - val_loss: 1.0558 - val_accuracy: 0.4667
# Epoch 8/20
# 11/11 [==============================] - 0s 14ms/step - loss: 0.9612 - accuracy: 0.5761 - val_loss: 1.0732 - val_accuracy: 0.4061
# Epoch 9/20
# 11/11 [==============================] - 0s 23ms/step - loss: 0.9579 - accuracy: 0.6985 - val_loss: 1.0821 - val_accuracy: 0.4303
# Epoch 10/20
# 11/11 [==============================] - 0s 13ms/step - loss: 0.8948 - accuracy: 0.6060 - val_loss: 1.0792 - val_accuracy: 0.4606
# Epoch 11/20
# 11/11 [==============================] - 0s 13ms/step - loss: 0.8569 - accuracy: 0.5940 - val_loss: 1.0814 - val_accuracy: 0.4424
# Epoch 12/20
# 11/11 [==============================] - 0s 14ms/step - loss: 0.8216 - accuracy: 0.6687 - val_loss: 1.1000 - val_accuracy: 0.4061
# Epoch 13/20
# 11/11 [==============================] - 0s 17ms/step - loss: 0.7706 - accuracy: 0.6896 - val_loss: 1.0980 - val_accuracy: 0.4121
# Epoch 14/20
# 11/11 [==============================] - 0s 14ms/step - loss: 0.7346 - accuracy: 0.7164 - val_loss: 1.1597 - val_accuracy: 0.4242
# Epoch 15/20
# 11/11 [==============================] - 0s 14ms/step - loss: 0.6864 - accuracy: 0.7731 - val_loss: 1.2071 - val_accuracy: 0.4000
# Epoch 16/20
# 11/11 [==============================] - 0s 13ms/step - loss: 0.6361 - accuracy: 0.7463 - val_loss: 1.2780 - val_accuracy: 0.4242
# Epoch 17/20
# 11/11 [==============================] - 0s 13ms/step - loss: 0.5985 - accuracy: 0.7612 - val_loss: 1.2689 - val_accuracy: 0.4545
# Epoch 18/20
# 11/11 [==============================] - 0s 13ms/step - loss: 0.5409 - accuracy: 0.7761 - val_loss: 1.2245 - val_accuracy: 0.4121
# Epoch 19/20
# 11/11 [==============================] - 0s 17ms/step - loss: 0.5077 - accuracy: 0.8090 - val_loss: 1.3444 - val_accuracy: 0.4121
# Epoch 20/20
# 11/11 [==============================] - 0s 14ms/step - loss: 0.4746 - accuracy: 0.8567 - val_loss: 1.4151 - val_accuracy: 0.4485

# %% [markdown]
# # Step 7: Prediction and Performation for Bidirectional LSTM

# %%
y_pred_bi=model.predict(X_test)
# y_pred=np.where(y_pred > 0.6, 1,0) ##AUC ROC Curve
y_pred_bi = (y_pred_bi > 0.2)
# Out:
# 6/6 [==============================] - 1s 5ms/step

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test,y_pred_bi))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.31      0.49      0.38        53
#            1       0.24      0.44      0.31        32
#            2       0.50      0.82      0.62        80
#
#    micro avg       0.39      0.64      0.48       165
#    macro avg       0.35      0.58      0.44       165
# weighted avg       0.39      0.64      0.48       165
#  samples avg       0.41      0.64      0.48       165

# %% [markdown]
# # End of BiDirectional LSTM
